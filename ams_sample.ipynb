# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/AMS_attendees.csv"
df_ams = pd.read_csv(path, names = ["attendee", "affiliation", "link", "letter"])

# %%
df_ams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4018 entries, 0 to 4017
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   attendee     4018 non-null   object
#  1   affiliation  3997 non-null   object
#  2   link         4018 non-null   object
#  3   letter       4018 non-null   object
# dtypes: object(4)
# memory usage: 125.7+ KB

# %%
df_ams.head()
# Out:
#                   attendee                                        affiliation  \
# 0              David Aasen                                Microsoft Station Q
# 1  Mohamed Abdelkader Abba                    North Carolina State University
# 2              Fazal Abbas  Mathematics and Computer Sciences, Stetson Uni...
# 3              Fazal Abbas  Mathematics and Computer Sciences, Stetson Uni...
# 4           Carolyn Abbott                                Brandeis University
#
#                                                 link letter
# 0  https://meetings.ams.org/math/jmm2022/meetinga...      A
# 1  https://meetings.ams.org/math/jmm2022/meetinga...      A
# 2  https://meetings.ams.org/math/jmm2022/meetinga...      A
# 3  https://meetings.ams.org/math/jmm2022/meetinga...      A
# 4  https://meetings.ams.org/math/jmm2022/meetinga...      A

# %%
np.random.seed(0)

# %%
df_ams_cleaned = df_ams[df_ams.affiliation.notnull()]

# %%
df_ams_cleaned
# Out:
#                      attendee  \
# 0                 David Aasen
# 1     Mohamed Abdelkader Abba
# 2                 Fazal Abbas
# 3                 Fazal Abbas
# 4              Carolyn Abbott
# ...                       ...
# 4013               Foling Zou
# 4014            Wadim Zudilin
# 4015          Alexander Zupan
# 4016          Alexander Zupan
# 4017              Inka Zörnig
#
#                                             affiliation  \
# 0                                   Microsoft Station Q
# 1                       North Carolina State University
# 2     Mathematics and Computer Sciences, Stetson Uni...
# 3     Mathematics and Computer Sciences, Stetson Uni...
# 4                                   Brandeis University
# ...                                                 ...
# 4013                             University of Michigan
# 4014                                 Radboud University
# 4015                     University of Nebraska-Lincoln
# ...

# %%
df_ams_sample = df_ams_cleaned.sample(n = 200, replace = False, random_state = 0)

# %%
df_ams_sample.to_csv("/content/drive/MyDrive/AMS_sample.csv")
